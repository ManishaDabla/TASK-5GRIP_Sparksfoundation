# %% [markdown]
#  ****************************************************************************************************************

# %% [markdown]
# # Data Science and Business Analytics Intern
# # Task #5 : Exploratory Data Analysis : Sports (Indian Premier League)
# # Dataset : https://bit.ly/34SRn3b

# %% [markdown]
#  ****************************************************************************************************************

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %%
print("Datesheet of Matches")
Data_1 = pd.read_csv("Matches_IPL.csv")
Data_1
# Out:
# Datesheet of Matches
#         id  season           city        date                        team1  \
# 0        1    2017      Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1        2    2017           Pune  2017-04-06               Mumbai Indians
# 2        3    2017         Rajkot  2017-04-07                Gujarat Lions
# 3        4    2017         Indore  2017-04-08       Rising Pune Supergiant
# 4        5    2017      Bangalore  2017-04-08  Royal Challengers Bangalore
# ..     ...     ...            ...         ...                          ...
# 751  11347    2019         Mumbai    05/05/19        Kolkata Knight Riders
# 752  11412    2019        Chennai    07/05/19          Chennai Super Kings
# 753  11413    2019  Visakhapatnam    08/05/19          Sunrisers Hyderabad
# 754  11414    2019  Visakhapatnam    10/05/19               Delhi Capitals
# 755  11415    2019      Hyderabad    12/05/19               Mumbai Indians
#
# ...

# %%
print("Datasheet of Deliveries")
Data_2 = pd.read_csv("Deliveries_IPL.csv")
Data_2
# Out:
# Datasheet of Deliveries
#         match_id  inning         batting_team                 bowling_team  \
# 0              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 1              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 2              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 3              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 4              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# ...          ...     ...                  ...                          ...
# 179073     11415       2  Chennai Super Kings               Mumbai Indians
# 179074     11415       2  Chennai Super Kings               Mumbai Indians
# 179075     11415       2  Chennai Super Kings               Mumbai Indians
# 179076     11415       2  Chennai Super Kings               Mumbai Indians
# 179077     11415       2  Chennai Super Kings               Mumbai Indians
#
# ...

# %%
print("Name of the teams:")
Data_2['batting_team'].unique()
# Out:
# Name of the teams:
# array(['Sunrisers Hyderabad', 'Royal Challengers Bangalore',
#        'Mumbai Indians', 'Rising Pune Supergiant', 'Gujarat Lions',
#        'Kolkata Knight Riders', 'Kings XI Punjab', 'Delhi Daredevils',
#        'Chennai Super Kings', 'Rajasthan Royals', 'Deccan Chargers',
#        'Kochi Tuskers Kerala', 'Pune Warriors', 'Rising Pune Supergiants',
#        'Delhi Capitals'], dtype=object)

# %%
print("No.of Super overs:")
Data_2['is_super_over'].value_counts()
# Out:
# No.of Super overs:
# 0    178997
# 1        81
# Name: is_super_over, dtype: int64

# %%
Season_data=Data_1[['id','season','winner']]
print("Complete Data after merging few columes of Matches_Data with Deliveries_Data which we required:")
Complete_data=Data_2.merge(Season_data,how='inner',left_on='match_id',right_on='id')
Complete_data
# Out:
# Complete Data after merging few columes of Matches_Data with Deliveries_Data which we required:
#         match_id  inning         batting_team                 bowling_team  \
# 0              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 1              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 2              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 3              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 4              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# ...          ...     ...                  ...                          ...
# 179073     11415       2  Chennai Super Kings               Mumbai Indians
# 179074     11415       2  Chennai Super Kings               Mumbai Indians
# 179075     11415       2  Chennai Super Kings               Mumbai Indians
# 179076     11415       2  Chennai Super Kings               Mumbai Indians
# ...

# %%
print("Columns of Matches_Data:")
Data_1.columns.values
# Out:
# Columns of Matches_Data:
# array(['id', 'season', 'city', 'date', 'team1', 'team2', 'toss_winner',
#        'toss_decision', 'result', 'dl_applied', 'winner', 'win_by_runs',
#        'win_by_wickets', 'player_of_match', 'venue', 'umpire1', 'umpire2',
#        'umpire3'], dtype=object)

# %%
Data_1 = Data_1.drop(columns=["umpire3"],axis=1)
print("Matches_Data after droping Umpire3 column:")
Data_1.head()
# Out:
# Matches_Data after droping Umpire3 column:
#    id  season       city        date                        team1  \
# 0   1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1   2    2017       Pune  2017-04-06               Mumbai Indians
# 2   3    2017     Rajkot  2017-04-07                Gujarat Lions
# 3   4    2017     Indore  2017-04-08       Rising Pune Supergiant
# 4   5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
# 2        Kolkata Knight Riders        Kolkata Knight Riders         field
# 3              Kings XI Punjab              Kings XI Punjab         field
# 4             Delhi Daredevils  Royal Challengers Bangalore           bat
#
#    result  dl_applied                       winner  win_by_runs  \
# ...

# %%
Countwins_per_season = Data_1.groupby("season")["winner"].value_counts()
print("No. of wins per season:")
Countwins_per_season
# Out:
# No. of wins per season:
# season  winner
# 2008    Rajasthan Royals               13
#         Kings XI Punjab                10
#         Chennai Super Kings             9
#         Delhi Daredevils                7
#         Mumbai Indians                  7
#                                        ..
# 2019    Kings XI Punjab                 6
#         Kolkata Knight Riders           6
#         Sunrisers Hyderabad             6
#         Rajasthan Royals                5
#         Royal Challengers Bangalore     5
# Name: winner, Length: 100, dtype: int64

# %%
plt.figure(figsize = (20,12))
sns.countplot(x='winner',data=Data_1,  color="pink")
plt.title("Plot of Numbers of matches won by team ",fontsize=30)
plt.xticks(rotation=90)
plt.xlabel("Teams",fontsize=20),
plt.ylabel("No of wins",fontsize=20)
plt.show()

# %%
plt.figure(figsize = (20,12))
sns.countplot('season',data=Data_1,palette="hsv")
plt.title("Plot of Number of Matches played in each IPL season",fontsize=30)
plt.xlabel("Season",fontsize=20)
plt.ylabel('Matches',fontsize=20)
plt.show()

# %%
print("Pie chart Plot on Toss Result")
Toss=Data_1.toss_decision.value_counts()
labels=np.array(Toss.index)
sizes = Toss.values
colors = ['pink', 'yellow']
plt.figure(figsize = (12,10))
plt.pie(sizes, labels=labels, colors=colors,autopct='%1.1f%%', shadow=True,startangle=90)
plt.title('Toss result',fontsize=30)
plt.show()
# Out:
# Pie chart Plot on Toss Result

# %%
plt.figure(figsize = (20,12))
sns.countplot('season',hue='toss_decision',data=Data_1,palette='winter')
plt.title("Plot of Numbers of matches won by Toss result ",fontsize=30)
plt.xlabel("Season",fontsize=20)
plt.ylabel("Count",fontsize=20)
plt.show()

# %%
print("Pie chart Plot on Match Result on the basis of Bat_first or Bowl_first")
Data_1['win_by']=np.where(Data_1['win_by_runs']>0,'Bat first','Bowl first')
Win=Data_1.win_by.value_counts()
labels=np.array(Win.index)
sizes = Win.values
colors = ['pink', 'yellow']
plt.figure(figsize = (12,10))
plt.pie(sizes, labels=labels, colors=colors,autopct='%1.1f%%', shadow=True,startangle=90)
plt.title('Match Result',fontsize=30)
plt.show()
# Out:
# Pie chart Plot on Match Result on the basis of Bat_first or Bowl_first

# %%
plt.figure(figsize = (20,12))
sns.countplot('season',hue='win_by',data=Data_1,palette='cool')
plt.title("Plot of Numbers of matches won by batting and bowling first ",fontsize=30)
plt.xlabel("Season",fontsize=20)
plt.ylabel("Count",fontsize=20)
plt.show()

# %%
print("Winners of Matches Season wise:")
Final_matches=Data_1.drop_duplicates(subset=['season'], keep='last')
Final_matches[['season','winner']].reset_index(drop=True).sort_values('season')
# Out:
# Winners of Matches Season wise:
#     season                 winner
# 1     2008       Rajasthan Royals
# 2     2009        Deccan Chargers
# 3     2010    Chennai Super Kings
# 4     2011    Chennai Super Kings
# 5     2012  Kolkata Knight Riders
# 6     2013         Mumbai Indians
# 7     2014  Kolkata Knight Riders
# 8     2015         Mumbai Indians
# 9     2016    Sunrisers Hyderabad
# 0     2017         Mumbai Indians
# 10    2018    Chennai Super Kings
# 11    2019         Mumbai Indians

# %%
print("Pie chart Plot on Winning percentage in final on the basis of what team chooses Bat/Field")
match = Final_matches.win_by.value_counts()
labels=np.array(Toss.index)
sizes = match.values
colors = ['violet', 'orange']
plt.figure(figsize = (12,10))
plt.pie(sizes, labels=labels, colors=colors,autopct='%1.1f%%', shadow=True,startangle=90)
plt.title('Match Result',fontsize=30)
plt.show()
# Out:
# Pie chart Plot on Winning percentage in final on the basis of what team chooses Bat/Field

# %%
print("Pie chart Plot on Winning percentage in final on the basis toss result")
Toss=Final_matches.toss_decision.value_counts()
labels=np.array(Toss.index)
sizes = Toss.values
colors = ['violet', 'orange']
plt.figure(figsize = (12,10))
plt.pie(sizes, labels=labels, colors=colors,autopct='%1.1f%%', shadow=True,startangle=90)
plt.title('Toss Result',fontsize=30)
plt.show()
# Out:
# Pie chart Plot on Winning percentage in final on the basis toss result

# %%
print("Toss_winner, Toss_decision, winner in final matches:")
Final_matches[['toss_winner','toss_decision','winner']].reset_index(drop=True)
# Out:
# Toss_winner, Toss_decision, winner in final matches:
#                     toss_winner toss_decision                 winner
# 0                Mumbai Indians           bat         Mumbai Indians
# 1              Rajasthan Royals         field       Rajasthan Royals
# 2   Royal Challengers Bangalore         field        Deccan Chargers
# 3           Chennai Super Kings           bat    Chennai Super Kings
# 4           Chennai Super Kings           bat    Chennai Super Kings
# 5           Chennai Super Kings           bat  Kolkata Knight Riders
# 6                Mumbai Indians           bat         Mumbai Indians
# 7         Kolkata Knight Riders         field  Kolkata Knight Riders
# 8           Chennai Super Kings         field         Mumbai Indians
# 9           Sunrisers Hyderabad           bat    Sunrisers Hyderabad
# 10          Chennai Super Kings         field    Chennai Super Kings
# 11               Mumbai Indians           bat         Mumbai Indians

# %%
print("Number of season won by teams:")
Final_matches["winner"].value_counts()
# Out:
# Number of season won by teams:
# Mumbai Indians           4
# Chennai Super Kings      3
# Kolkata Knight Riders    2
# Rajasthan Royals         1
# Deccan Chargers          1
# Sunrisers Hyderabad      1
# Name: winner, dtype: int64

# %%
print("IPL Finals venues and winners along with the number of wins:")
Final_matches.groupby(['city','winner']).size()
# Out:
# IPL Finals venues and winners along with the number of wins:
# city          winner
# Bangalore     Kolkata Knight Riders    1
#               Sunrisers Hyderabad      1
# Chennai       Chennai Super Kings      1
#               Kolkata Knight Riders    1
# Hyderabad     Mumbai Indians           2
# Johannesburg  Deccan Chargers          1
# Kolkata       Mumbai Indians           2
# Mumbai        Chennai Super Kings      2
#               Rajasthan Royals         1
# dtype: int64

# %%
print("Name of top players in IPL:")
plt.figure(figsize = (18,10))
top_players = Data_1.player_of_match.value_counts()[:10]
fig, ax = plt.subplots()
ax.set_ylim([0,20])
ax.set_ylabel("Count")
ax.set_title("Top player of the match Winners")
top_players.plot.bar()
sns.barplot(x = top_players.index, y = top_players, orient='v', color="violet");
plt.show()
# Out:
# Name of top players in IPL:

# %%
print("Man of the match of winning team:")
Final_matches[['winner','player_of_match']].reset_index(drop=True)
# Out:
# Man of the match of winning team:
#                    winner player_of_match
# 0          Mumbai Indians       KH Pandya
# 1        Rajasthan Royals       YK Pathan
# 2         Deccan Chargers        A Kumble
# 3     Chennai Super Kings        SK Raina
# 4     Chennai Super Kings         M Vijay
# 5   Kolkata Knight Riders        MS Bisla
# 6          Mumbai Indians      KA Pollard
# 7   Kolkata Knight Riders       MK Pandey
# 8          Mumbai Indians       RG Sharma
# 9     Sunrisers Hyderabad     BCJ Cutting
# 10    Chennai Super Kings       SR Watson
# 11         Mumbai Indians       JJ Bumrah

# %%
print("No. of matches won after wining the toss in Final_matches:")
len(Final_matches[Final_matches['toss_winner']==Final_matches['winner']]['winner'])
# Out:
# No. of matches won after wining the toss in Final_matches:
# 9

# %%
print("Numbers of fours hit by team:")
No_of_four=Complete_data[Complete_data['batsman_runs']==4]
No_of_four.groupby('batting_team')['batsman_runs'].agg([('runs by fours','sum'),('fours','count')])
# Out:
# Numbers of fours hit by team:
#                              runs by fours  fours
# batting_team
# Chennai Super Kings                   8772   2193
# Deccan Chargers                       3828    957
# Delhi Capitals                         968    242
# Delhi Daredevils                      8632   2158
# Gujarat Lions                         1840    460
# Kings XI Punjab                       9832   2458
# Kochi Tuskers Kerala                   680    170
# Kolkata Knight Riders                 9736   2434
# Mumbai Indians                       10352   2588
# Pune Warriors                         2100    525
# Rajasthan Royals                      8140   2035
# Rising Pune Supergiant                 788    197
# Rising Pune Supergiants                684    171
# Royal Challengers Bangalore           9440   2360
# Sunrisers Hyderabad                   5776   1444

# %%
ax=No_of_four.groupby('season')['batsman_runs'].agg([('four','count')]).reset_index().plot('season','four',kind='bar',color = 'violet')
plt.title("Plot of Numbers of fours hit in each season ",fontsize=30)
plt.xticks(rotation=90)
plt.xlabel("season",fontsize=20)
plt.ylabel("No of fours",fontsize=20)
plt.show()

# %%
Four_of_batsman=No_of_four.groupby('batsman')['batsman_runs'].agg([('four','count')]).reset_index().sort_values('four',ascending=0)
ax=Four_of_batsman.iloc[:10,:].plot('batsman','four',kind='bar',color='pink')
plt.title("Plot of Numbers of fours hit by players ",fontsize=30)
plt.xticks(rotation=90)
plt.xlabel("Player name",fontsize=20)
plt.ylabel("No of fours",fontsize=20)
plt.show()

# %%
print("Numbers of sixes hit by team:")
No_of_six=Complete_data[Complete_data['batsman_runs']==6]
No_of_six.groupby('batting_team')['batsman_runs'].agg([('runs by six','sum'),('sixes','count')])
# Out:
# Numbers of sixes hit by team:
#                              runs by six  sixes
# batting_team
# Chennai Super Kings                 5838    973
# Deccan Chargers                     2400    400
# Delhi Capitals                       522     87
# Delhi Daredevils                    4806    801
# Gujarat Lions                        930    155
# Kings XI Punjab                     5856    976
# Kochi Tuskers Kerala                 318     53
# Kolkata Knight Riders               5580    930
# Mumbai Indians                      6576   1096
# Pune Warriors                       1176    196
# Rajasthan Royals                    4086    681
# Rising Pune Supergiant               534     89
# Rising Pune Supergiants              408     68
# Royal Challengers Bangalore         6792   1132
# Sunrisers Hyderabad                 3198    533

# %%
ax=No_of_six.groupby('season')['batsman_runs'].agg([('six','count')]).reset_index().plot('season','six',kind='bar',color = 'violet')
plt.title("Plot of Numbers of Sixes hit in each season ",fontsize=30)
plt.xticks(rotation=90)
plt.xlabel("season",fontsize=20)
plt.ylabel("No of fours",fontsize=20)
plt.show()

# %%
Six_of_batsman=No_of_six.groupby('batsman')['batsman_runs'].agg([('six','count')]).reset_index().sort_values('six',ascending=0)
ax=Six_of_batsman.iloc[:10,:].plot('batsman','six',kind='bar',color='pink')
plt.title("Numbers of six hit by players ",fontsize=30)
plt.xticks(rotation=90)
plt.xlabel("Player name",fontsize=20)
plt.ylabel("No of six",fontsize=20)
plt.show()

# %%
print("No. of matches played by batsman are:")
Player_matches= Data_2[["match_id","player_dismissed"]]
Player_matches=Player_matches .groupby("player_dismissed")["match_id"].count().reset_index().sort_values(by="match_id",ascending=False).reset_index(drop=True)
Player_matches.columns=["batsman","No_of Matches"]
Player_matches
# Out:
# No. of matches played by batsman are:
#              batsman  No_of Matches
# 0           SK Raina            162
# 1          RG Sharma            155
# 2         RV Uthappa            153
# 3            V Kohli            143
# 4           S Dhawan            137
# ..               ...            ...
# 482          C Madan              1
# 483  SMSM Senanayake              1
# 484         P Chopra              1
# 485        P Krishna              1
# 486        M Santner              1
#
# [487 rows x 2 columns]

# %%
print("Top 5 highest no. of matches played by players are:")
Player_matches.head(5)
# Out:
# Top 5 highest no. of matches played by players are:
#       batsman  No_of Matches
# 0    SK Raina            162
# 1   RG Sharma            155
# 2  RV Uthappa            153
# 3     V Kohli            143
# 4    S Dhawan            137

# %%
print("Least no. of matches played by players are:")
Player_matches.tail(5)
# Out:
# Least no. of matches played by players are:
#              batsman  No_of Matches
# 482          C Madan              1
# 483  SMSM Senanayake              1
# 484         P Chopra              1
# 485        P Krishna              1
# 486        M Santner              1

# %%
Score_of_batsman=Data_2.groupby('batsman')['batsman_runs'].agg(['sum']).reset_index().sort_values('sum',ascending=False).reset_index(drop=True)
Score_of_batsman=Score_of_batsman.rename(columns={'sum':'batsman_runs'})
print("Top 10 Leading Run Scorer in IPL:")
Score_of_batsman.iloc[:10,:]
# Out:
# Top 10 Leading Run Scorer in IPL:
#           batsman  batsman_runs
# 0         V Kohli          5434
# 1        SK Raina          5415
# 2       RG Sharma          4914
# 3       DA Warner          4741
# 4        S Dhawan          4632
# 5        CH Gayle          4560
# 6        MS Dhoni          4477
# 7      RV Uthappa          4446
# 8  AB de Villiers          4428
# 9       G Gambhir          4223

# %%
plt.figure(figsize=(20,12))
ax=sns.countplot(Data_2.dismissal_kind, color="pink")
plt.title("Dismissals in IPL",fontsize=30)
plt.xlabel("Dismissals kind",fontsize=20)
plt.ylabel("count",fontsize=20)
plt.xticks(rotation=50)
plt.show()

# %%
No_of_wicket=Data_2.dropna(subset=['dismissal_kind'])
No_of_wicket=No_of_wicket[~No_of_wicket['dismissal_kind'].isin(['run out','retired hurt','obstructing the field'])]
print("Top wicket taking bowlers in IPL are:")
No_of_wicket.groupby('bowler')['dismissal_kind'].agg(['count']).reset_index().sort_values('count',ascending=False).reset_index(drop=True).iloc[:10,:]
# Out:
# Top wicket taking bowlers in IPL are:
#             bowler  count
# 0       SL Malinga    170
# 1         A Mishra    156
# 2  Harbhajan Singh    150
# 3        PP Chawla    149
# 4         DJ Bravo    147
# 5          B Kumar    133
# 6         R Ashwin    125
# 7        SP Narine    122
# 8         UT Yadav    119
# 9        RA Jadeja    108

# %% [markdown]
# ****************************************************************************************************************

# %% [markdown]
# # CONCULSION Of Above Exploratory Data Analysis

# %% [markdown]
# 1. TEAM NAMES: Sunrisers Hyderabad, Royal Challengers Bangalore, Mumbai Indians, Rising Pune Supergiant, Gujarat Lions, Kolkata Knight Riders, Kings XI Punjab, Delhi Daredevils, Chennai Super Kings, Rajasthan Royals, Deccan Chargers, Kochi Tuskers Kerala, Pune Warriors, Rising Pune Supergiants, Delhi Capitals
# 1. The highest number of match won by Mumbai Indians i.e 4 match out of 12 matches.
# 2. The highest number of match played in IPL season was 2013,2014,2015.
# 3. Teams which Bowl first has higher chances of winning then the team which bat first.
# 4. After winning toss more teams decide to do fielding first.
# 5. In finals teams which decide to do fielding first win the matches more then the team which bat first.
# 6. In finals most teams after winning toss decide to do fielding first.
# 7. Top player of match winning are CH gayle, AB de villers.
# 8. It is interesting that out of 12 IPL finals,9 times the team that won the toss was also the winner of IPL.
# 9. The highest number of four hit by player is Shikar Dhawan.
# 10. The highest number of six hit by player is CH gayle.
# 11. The maximun number of matches are win by Muumbai Indians.
# 11. There are 487 players who played the matches.
# 12. The highest number of matches played by player name are SK Raina, RG Sharma.
# 13. The least number of matches played by player name are P Krishna, M Santner.
# 14. Top leading run scorer in IPL are Virat kholi, SK Raina, RG Sharma.
# 15. Dismissals in IPL was most by Catch out .
# 16. The IPL most wicket taken blower is SL Malinga.

# %% [markdown]
# ****************************************************************************************************************

# %% [markdown]
# # Thank You
# # -Manisha
